# %%
import numpy as np
from scipy import stats

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import classification_report, confusion_matrix

# %%
def prepare_data(n, model=None, start=False, n_bids=100):

    ############ FIRST ROUND

    # valuations and actions of the player
    r1_remain_player   = np.random.beta(1,1,n)
    r1_action_player  = np.random.beta(1,1,n)
    r1_remain_opponent = np.random.beta(1,1,n)

    # if first iteration - opponent plays randomly
    if start==True:
        r1_action_opponent = np.random.beta(1,1,n)
    else:
        # opponent chooses optimal bid given his valuation
        X_r1_opponent = np.concatenate((np.repeat(0, n).reshape(n,1),
                                        np.repeat(0, n).reshape(n,1),
                                        (r1_remain_opponent + np.random.beta(1,1,n)/1000).reshape(n,1),
                                        np.repeat(0, n).reshape(n,1),
                                        np.repeat(0, n).reshape(n,1)), axis=1)
        
        X_r1_opponent = np.repeat(X_r1_opponent, n_bids, axis=0)
        action_opponent = np.tile(np.linspace(start=0, stop=1, num=n_bids), n)
        
        # gather private values and bids together
        X_r1_opponent = np.concatenate((X_r1_opponent, action_opponent.reshape(n*n_bids,1)), axis=1)
        
        # determine optimal bid
        X_r1_opponent = opt_bid(model, X_r1_opponent)
        r1_remain_opponent = X_r1_opponent[:,0]
        r1_action_opponent = X_r1_opponent[:,1]
        print("# Determined opt bids R1")
    
    # determine bids and winner of the first round
    r1_bid_player   = r1_remain_player*r1_action_player
    r1_bid_opponent = r1_remain_opponent*r1_action_opponent
    r1_winner = (r1_bid_player>r1_bid_opponent)
    print("# End of R1")

    ############ SECOND ROUND
    r2_remain_player = r1_remain_player - r1_bid_player
    r2_remain_opponent = r1_remain_opponent - r1_bid_opponent

    #### CASE 1. Player lost R1 and Opponents r1_bid_opponent > r1_remain_player


    #### CASE 2.Player lost R1 and Opponents r1_bid_opponent < r1_remain_player

    # bid if lost first round
    r2_act_lost_player = np.random.beta(1,1,n)
    if start==True:
        r2_act_lost_opponent = np.random.beta(1,1,n)
    else:
        # remeber order of r2_remain_opponent to sort all other arrays
        r2_remain_opponent = r1_remain_opponent-r1_bid_opponent
        r2_sort = np.argsort(r2_remain_opponent)
        
        # opponent chooses optimal bid given his valuation and bid of the player
        X_r2_opponent = np.concatenate((np.repeat(1, n).reshape(n,1),
                                        r1_bid_opponent.reshape(n,1),
                                        (r2_remain_opponent + np.random.beta(1,1,n)/1000).reshape(n,1),
                                        np.repeat(0, n).reshape(n,1),
                                        r1_bid_player.reshape(n,1)), axis=1)
        
        X_r2_opponent = np.repeat(X_r2_opponent, n_bids, axis=0)
        action_opponent = np.tile(np.linspace(start=0, stop=1, num=n_bids), n)
        
        # gather private values and bids together
        X_r2_opponent = np.concatenate((X_r2_opponent, action_opponent.reshape(n*n_bids,1)), axis=1)
        
        # determine optimal bid
        X_r2_opponent = opt_bid(model, X_r2_opponent)
        r2_remain_opponent = X_r2_opponent[:,0]
        r2_act_lost_opponent = X_r2_opponent[:,1]
        
        # sort other arrays
        r1_remain_player = r1_remain_player[r2_sort]
        r1_remain_opponent = r1_remain_opponent[r2_sort]
        r1_bid_opponent = r1_bid_opponent[r2_sort]
        r1_bid_player = r1_bid_player[r2_sort]
        r1_action_player = r1_action_player[r2_sort]
        r1_action_opponent = r1_action_opponent[r2_sort]
        r1_winner = r1_winner[r2_sort]
        r2_act_lost_player = r2_act_lost_player[r2_sort]
        r2_remain_player = r2_remain_player[r2_sort]
        print("# Determined opt bids R2")
        
    
    # condition for case 2
    r2_case2_cond_player = (r1_remain_player>r1_bid_opponent)*(1-r1_winner)
    
    # absolute bid
    r2_bid_lost_player = (r1_bid_opponent-r1_bid_player) + (r1_remain_player-r1_bid_opponent)*r2_act_lost_player
    r2_bid_lost_opponent = (r1_bid_player-r1_bid_opponent) + (r1_remain_opponent-r1_bid_player)*r2_act_lost_opponent

    # player wins after losing 1st round if sum of his bids>private value of opponent
    r2_cond_win_lostr1 = (r1_bid_player+r2_bid_lost_player)>r1_remain_opponent
    profit_lost_r1 = (r2_remain_player - r2_bid_lost_player)*(r2_cond_win_lostr1*r2_case2_cond_player)


    ### CASE 3. Won the first round (r1_bid_opponent+r2_bid_lost_opponent) < r1_bid_player
    r2_case3_cond_player = r1_remain_opponent<r1_bid_player
    profit_win_r1_case3 = r2_remain_player*r2_case3_cond_player

    ### Case 4. Won the first round (r1_bid_opponent+r2_bid_lost_opponent) > r1_bid_player

    # condition for case 3
    r2_case4_cond1_player = ((r1_bid_opponent+r2_bid_lost_opponent)>r1_bid_player)
    r2_case4_cond2_player = ((r1_bid_opponent+r2_bid_lost_opponent)<r1_remain_player)

    # player sees both bids of the opponent and only adds marginal value to win the auction
    profit_win_r1_case4 = (r1_remain_player - r1_bid_opponent - r2_bid_lost_opponent - 0.0000001)*r2_case4_cond1_player*r2_case4_cond2_player*r1_winner

    ### Final value of profit for player
    profit = profit_lost_r1 + profit_win_r1_case3 + profit_win_r1_case4
    
    res = [r1_remain_player, r1_action_player, r1_bid_player, r1_bid_opponent, r1_winner, 
    r2_remain_player, r2_act_lost_player, r2_case2_cond_player, profit]
    
    return res

# %%
def prepare_data_fit(r1_remain_player, r1_action_player, r1_bid_player, r1_bid_opponent, r1_winner,
                     r2_remain_player, r2_act_lost_player, r2_case2_cond_player, profit):


    X_r1 = np.concatenate((np.repeat(0, n).reshape(n,1),
                           np.repeat(0, n).reshape(n,1),
                           r1_remain_player.reshape(n,1),
                           np.repeat(0, n).reshape(n,1),
                           np.repeat(0, n).reshape(n,1),
                           r1_action_player.reshape(n,1),
                           profit.reshape(n,1)), axis=1)
                       
    X_r2 = np.concatenate((np.repeat(1, n).reshape(n,1),
                           r1_bid_player.reshape(n,1),
                           r2_remain_player.reshape(n,1),
                           r1_winner.reshape(n,1),
                           r1_bid_opponent.reshape(n,1),
                           r2_act_lost_player.reshape(n,1),
                           profit.reshape(n,1),
                           r2_case2_cond_player.reshape(n,1)), axis=1)

    # keep only those instances from R2 where r2_case2_cond_player=True
    X_r2 = X_r2[X_r2[:,7]==1,0:7]

    # concatenate results of both rounds
    X = np.concatenate((X_r1, X_r2), axis=0)

    # separate profit
    y = X[:,-1]
    X = X[:,0:6]
    
    return X, y

# %%
def fit_model(X, y):
    
    # create a neural network
    mlp = MLPRegressor(alpha=0.001, hidden_layer_sizes = (10,5,3), max_iter = 1000, 
                   activation = 'logistic', verbose = True, learning_rate = 'adaptive')
    # fit model
    mlp.fit(X, y)
    
    return mlp

# %%
def track_progress(model):
    n_val = 5
    n_bids = 100
    n_total = n_val*n_bids
    
    ### First round 
    X_r1 = np.concatenate((np.repeat(0, n_val).reshape(n_val,1),
                        np.repeat(0, n_val).reshape(n_val,1),
                        np.array([0.1, 0.3, 0.5, 0.7, 0.9]).reshape(n_val,1),
                        np.repeat(0, n_val).reshape(n_val,1),
                        np.repeat(0, n_val).reshape(n_val,1)), axis=1)

    # create private values and bids
    X_r1 = np.repeat(X_r1, n_bids, axis=0)
    action_player = np.tile(np.linspace(start=0, stop=1, num=n_bids), n_val)

    # gather private values and bids together
    X_r1 = np.concatenate((X_r1, action_player.reshape(n_total,1)), axis=1)
    
    X_r1 = opt_bid(model, X_r1)
    
    ### Second round
    X_r2 = np.concatenate((np.repeat(1, n_val).reshape(n_val,1),
                          (X_r1[:,0]*X_r1[:,1]).reshape(n_val,1),
                          (X_r1[:,0] - X_r1[:,0]*X_r1[:,1]).reshape(n_val,1),
                           np.repeat(0, n_val).reshape(n_val,1),
                          (X_r1[:,0]*X_r1[:,1] + (X_r1[:,0] - X_r1[:,0]*X_r1[:,1])*0.5).reshape(n_val,1)), axis=1)
                          
    X_r2 = np.repeat(X_r2, n_bids, axis=0)
    X_r2 = np.concatenate((X_r2, action_player.reshape(n_total,1)), axis=1)
    
    X_r2 = opt_bid(model, X_r2)
    
    return X_r1, X_r2

def opt_bid(model, X):
    '''Find bid with the highest expected profit'''
    
    # predict expected profit for each pair
    cand_predict = model.predict(X)
    cand_predict[cand_predict <= 0] = 0
    cand_predict[cand_predict >= 1] = 1

    # add expected profit to cand
    cand_res = np.concatenate((X, cand_predict.reshape(X.shape[0],1)), axis=1)

    # sort cand_res in descending order by the expected profit
    cand_res = cand_res[cand_res[:,-1].argsort()[::-1],:]

    # keep only best bids
    unique_keys, indices = np.unique(cand_res[:,2], return_index=True)
    cand_res = cand_res[indices,:]
    
    
    return cand_res[:,[2,5,6]]

# %%
#### Run algorithm

np.random.seed(5)
n = 1000000

vector_opt_bids_r1 = np.array([0.1, 0.3, 0.5, 0.7, 0.9]).reshape(5,1)
vector_opt_bids_r2 = np.array([0.1, 0.3, 0.5, 0.7, 0.9]).reshape(5,1)

for iter in range(20):
    
    print("########## Iteration: ", iter, "\n")
    
    # prepare data
    if iter==0:
        inputs = prepare_data(n, model=None, start=True)
    else:
        inputs = prepare_data(n, model=mlp, start=False)
        # save this model
        mlp_prev = mlp

    X, y = prepare_data_fit(inputs[0],inputs[1],inputs[2],inputs[3],inputs[4],inputs[5],
                            inputs[6],inputs[7],inputs[8])

    mlp = fit_model(X, y)

    # print optimal bids
    check_R1, check_R2 = track_progress(mlp)
    vector_opt_bids_r1 = np.concatenate((vector_opt_bids_r1, check_R1[:,1].reshape(5,1)), axis=1)
    vector_opt_bids_r2 = np.concatenate((vector_opt_bids_r2, check_R2[:,1].reshape(5,1)), axis=1)

    print("First round:")
    print(vector_opt_bids_r1[:,[0,-1]])

    print("Second round:")
    print(vector_opt_bids_r2[:,[0,-1]])
    
    # if there are extreme values in vector_opt_bids - repeat the iteration
    if (np.sum(vector_opt_bids_r1[:,-1]==0) + np.sum(vector_opt_bids_r1[:,-1]==1))!=0:
        print("Repeating iteration. Extreme values in 1st round")
        mlp = mlp_prev
    elif (np.sum(vector_opt_bids_r2[:,-1]==0) + np.sum(vector_opt_bids_r2[:,-1]==1))!=0:
        print("Repeating iteration. Extreme values in 2nd round")
        mlp = mlp_prev

    del X,y
# Out:
# ########## Iteration:  0
#
# # End of R1
# Iteration 1, loss = 0.00926542
# Iteration 2, loss = 0.00828816
# Iteration 3, loss = 0.00806896
# Iteration 4, loss = 0.00772588
# Iteration 5, loss = 0.00766246
# Iteration 6, loss = 0.00764256
# Iteration 7, loss = 0.00762859
# Iteration 8, loss = 0.00761596
# Iteration 9, loss = 0.00760509
# Iteration 10, loss = 0.00759514
# Iteration 11, loss = 0.00758554
# Iteration 12, loss = 0.00757821
# Iteration 13, loss = 0.00757001
# Iteration 14, loss = 0.00756409
# Iteration 15, loss = 0.00755772
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# First round:
# [[0.1        0.45454545]
#  [0.3        0.4040404 ]
#  [0.5        0.37373737]
#  [0.7        0.34343434]
#  [0.9        0.32323232]]
# Second round:
# [[0.1        0.8989899 ]
#  [0.3        0.52525253]
#  [0.5        0.51515152]
#  [0.7        0.51515152]
#  [0.9        0.51515152]]
# ########## Iteration:  1
#
# # Determined opt bids R1
# # End of R1
# # Determined opt bids R2
# Iteration 1, loss = 0.01640925
# Iteration 2, loss = 0.00741486
# Iteration 3, loss = 0.00646975
# Iteration 4, loss = 0.00627814
# Iteration 5, loss = 0.00622218
# Iteration 6, loss = 0.00618912
# Iteration 7, loss = 0.00616774
# Iteration 8, loss = 0.00615129
# Iteration 9, loss = 0.00614129
# Iteration 10, loss = 0.00613353
# Iteration 11, loss = 0.00612606
# Iteration 12, loss = 0.00611932
# Iteration 13, loss = 0.00611411
# Iteration 14, loss = 0.00610799
# Iteration 15, loss = 0.00610294
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# First round:
# [[0.1        0.49494949]
#  [0.3        0.43434343]
#  [0.5        0.4040404 ]
#  [0.7        0.39393939]
#  [0.9        0.38383838]]
# Second round:
# [[0.1        0.60606061]
#  [0.3        0.92929293]
#  [0.5        0.01010101]
#  [0.7        0.75757576]
#  [0.9        1.        ]]
# Repeating iteration. Extreme values in 2nd round
# ########## Iteration:  2
#
# # Determined opt bids R1
# # End of R1
# # Determined opt bids R2
# Iteration 1, loss = 0.01448026
# Iteration 2, loss = 0.00765016
# Iteration 3, loss = 0.00753238
# Iteration 4, loss = 0.00671964
# Iteration 5, loss = 0.00629574
# Iteration 6, loss = 0.00621361
# Iteration 7, loss = 0.00616539
# Iteration 8, loss = 0.00612746
# Iteration 9, loss = 0.00609884
# Iteration 10, loss = 0.00607642
# Iteration 11, loss = 0.00605807
# Iteration 12, loss = 0.00604193
# Iteration 13, loss = 0.00603028
# Iteration 14, loss = 0.00601894
# Iteration 15, loss = 0.00600930
# Iteration 16, loss = 0.00600141
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# First round:
# [[0.1        0.60606061]
#  [0.3        0.45454545]
#  [0.5        0.4040404 ]
#  [0.7        0.38383838]
#  [0.9        0.37373737]]
# Second round:
# [[0.1        0.75757576]
#  [0.3        0.        ]
#  [0.5        0.        ]
#  [0.7        0.        ]
#  [0.9        0.16161616]]
# Repeating iteration. Extreme values in 2nd round
# ########## Iteration:  3
#
# # Determined opt bids R1
# # End of R1
# # Determined opt bids R2
# Iteration 1, loss = 0.01694368
# Iteration 2, loss = 0.00764348
# Iteration 3, loss = 0.00760321
# Iteration 4, loss = 0.00758168
# Iteration 5, loss = 0.00756568
# Iteration 6, loss = 0.00754979
# Iteration 7, loss = 0.00753686
# Iteration 8, loss = 0.00752271
# Iteration 9, loss = 0.00750759
# Iteration 10, loss = 0.00748917
# Iteration 11, loss = 0.00745956
# Iteration 12, loss = 0.00740134
# Iteration 13, loss = 0.00723790
# Iteration 14, loss = 0.00645443
# Iteration 15, loss = 0.00612557
# Iteration 16, loss = 0.00606365
# Iteration 17, loss = 0.00603287
# Iteration 18, loss = 0.00601295
# Iteration 19, loss = 0.00599898
# Iteration 20, loss = 0.00599143
# Iteration 21, loss = 0.00598128
# Iteration 22, loss = 0.00597680
# Iteration 23, loss = 0.00597090
# Iteration 24, loss = 0.00596472
# Iteration 25, loss = 0.00596286
# Iteration 26, loss = 0.00595949
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# First round:
# [[0.1        0.54545455]
#  [0.3        0.43434343]
#  [0.5        0.41414141]
#  [0.7        0.39393939]
#  [0.9        0.38383838]]
# Second round:
# [[0.1        1.        ]
#  [0.3        0.        ]
#  [0.5        0.        ]
#  [0.7        0.76767677]
#  [0.9        0.26262626]]
# Repeating iteration. Extreme values in 2nd round
# ########## Iteration:  4
#
# # Determined opt bids R1
# # End of R1
# # Determined opt bids R2
# Iteration 1, loss = 0.01470344
# Iteration 2, loss = 0.00715263
# Iteration 3, loss = 0.00643564
# Iteration 4, loss = 0.00630995
# Iteration 5, loss = 0.00625720
# Iteration 6, loss = 0.00622607
# Iteration 7, loss = 0.00619938
# Iteration 8, loss = 0.00617924
# Iteration 9, loss = 0.00616459
# Iteration 10, loss = 0.00615075
# Iteration 11, loss = 0.00613507
# Iteration 12, loss = 0.00612006
# Iteration 13, loss = 0.00610699
# Iteration 14, loss = 0.00609752
# Iteration 15, loss = 0.00609143
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# First round:
# [[0.1        0.55555556]
#  [0.3        0.44444444]
#  [0.5        0.41414141]
#  [0.7        0.39393939]
#  [0.9        0.38383838]]
# Second round:
# [[0.1        0.7979798 ]
#  [0.3        0.95959596]
#  [0.5        0.08080808]
#  [0.7        0.75757576]
#  [0.9        0.98989899]]
# ########## Iteration:  5
#
# # Determined opt bids R1
# # End of R1
# # Determined opt bids R2
# Iteration 1, loss = 0.00832614
# Iteration 2, loss = 0.00765954
# Iteration 3, loss = 0.00718498
# Iteration 4, loss = 0.00668717
# Iteration 5, loss = 0.00662107
# Iteration 6, loss = 0.00659382
# Iteration 7, loss = 0.00656910
# Iteration 8, loss = 0.00654820
# Iteration 9, loss = 0.00652817
# Iteration 10, loss = 0.00651258
# Iteration 11, loss = 0.00649622
# Iteration 12, loss = 0.00648355
# Iteration 13, loss = 0.00646846
# Iteration 14, loss = 0.00645325
# Iteration 15, loss = 0.00643784
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# First round:
# [[0.1        0.48484848]
#  [0.3        0.44444444]
#  [0.5        0.41414141]
#  [0.7        0.4040404 ]
#  [0.9        0.39393939]]
# Second round:
# [[0.1        0.51515152]
#  [0.3        0.63636364]
#  [0.5        0.38383838]
#  [0.7        0.75757576]
#  [0.9        1.        ]]
# Repeating iteration. Extreme values in 2nd round
# ########## Iteration:  6
#
# # Determined opt bids R1
# # End of R1
# # Determined opt bids R2
# Iteration 1, loss = 0.00845899
# Iteration 2, loss = 0.00761175
# Iteration 3, loss = 0.00745219
# Iteration 4, loss = 0.00673462
# Iteration 5, loss = 0.00646779
# Iteration 6, loss = 0.00641853
# Iteration 7, loss = 0.00638666
# Iteration 8, loss = 0.00636436
# Iteration 9, loss = 0.00634519
# Iteration 10, loss = 0.00633147
# Iteration 11, loss = 0.00631944
# Iteration 12, loss = 0.00630956
# Iteration 13, loss = 0.00630365
# Iteration 14, loss = 0.00629829
# Iteration 15, loss = 0.00629231
# Iteration 16, loss = 0.00628685
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# First round:
# [[0.1        0.55555556]
#  [0.3        0.47474747]
#  [0.5        0.42424242]
#  [0.7        0.4040404 ]
#  [0.9        0.39393939]]
# Second round:
# [[0.1        0.60606061]
#  [0.3        0.7979798 ]
#  [0.5        0.        ]
#  [0.7        0.19191919]
#  [0.9        0.3030303 ]]
# Repeating iteration. Extreme values in 2nd round
# ########## Iteration:  7
#
# # Determined opt bids R1
# # End of R1
# # Determined opt bids R2
# Iteration 1, loss = 0.00950303
# Iteration 2, loss = 0.00769760
# Iteration 3, loss = 0.00754134
# Iteration 4, loss = 0.00696195
# Iteration 5, loss = 0.00679942
# Iteration 6, loss = 0.00674112
# Iteration 7, loss = 0.00670413
# Iteration 8, loss = 0.00667820
# Iteration 9, loss = 0.00665590
# Iteration 10, loss = 0.00663535
# Iteration 11, loss = 0.00660899
# Iteration 12, loss = 0.00657937
# Iteration 13, loss = 0.00654605
# Iteration 14, loss = 0.00651540
# Iteration 15, loss = 0.00649114
# Iteration 16, loss = 0.00647279
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# First round:
# [[0.1        0.47474747]
#  [0.3        0.4040404 ]
#  [0.5        0.36363636]
#  [0.7        0.36363636]
#  [0.9        0.38383838]]
# Second round:
# [[0.1        0.48484848]
#  [0.3        0.65656566]
#  [0.5        0.26262626]
#  [0.7        0.        ]
#  [0.9        0.        ]]
# Repeating iteration. Extreme values in 2nd round
# ########## Iteration:  8
#
# # Determined opt bids R1
# # End of R1
# # Determined opt bids R2
# Iteration 1, loss = 0.00813282
# Iteration 2, loss = 0.00760681
# Iteration 3, loss = 0.00705968
# Iteration 4, loss = 0.00664201
# Iteration 5, loss = 0.00655332
# Iteration 6, loss = 0.00651551
# Iteration 7, loss = 0.00649188
# Iteration 8, loss = 0.00647305
# Iteration 9, loss = 0.00645759
# Iteration 10, loss = 0.00644532
# Iteration 11, loss = 0.00643279
# Iteration 12, loss = 0.00642021
# Iteration 13, loss = 0.00640981
# Iteration 14, loss = 0.00640091
# Iteration 15, loss = 0.00639243
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# First round:
# [[0.1        0.51515152]
#  [0.3        0.46464646]
#  [0.5        0.42424242]
#  [0.7        0.4040404 ]
#  [0.9        0.39393939]]
# Second round:
# [[0.1        0.54545455]
#  [0.3        0.66666667]
#  [0.5        0.        ]
#  [0.7        0.75757576]
#  [0.9        1.        ]]
# Repeating iteration. Extreme values in 2nd round
# ########## Iteration:  9
#
# # Determined opt bids R1
# # End of R1
# # Determined opt bids R2
# Iteration 1, loss = 0.01477651
# Iteration 2, loss = 0.00731903
# Iteration 3, loss = 0.00670952
# Iteration 4, loss = 0.00660983
# Iteration 5, loss = 0.00657457
# Iteration 6, loss = 0.00655524
# Iteration 7, loss = 0.00653959
# Iteration 8, loss = 0.00652647
# Iteration 9, loss = 0.00651474
# Iteration 10, loss = 0.00650579
# Iteration 11, loss = 0.00649635
# Iteration 12, loss = 0.00649031
# Iteration 13, loss = 0.00648310
# Iteration 14, loss = 0.00647600
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# First round:
# [[0.1        0.55555556]
#  [0.3        0.48484848]
#  [0.5        0.43434343]
#  [0.7        0.41414141]
#  [0.9        0.39393939]]
# Second round:
# [[0.1        0.60606061]
#  [0.3        0.72727273]
#  [0.5        0.04040404]
#  [0.7        0.75757576]
#  [0.9        0.98989899]]
# ########## Iteration:  10
#
# # Determined opt bids R1
# # End of R1
# # Determined opt bids R2
# Iteration 1, loss = 0.00815267
# Iteration 2, loss = 0.00764385
# Iteration 3, loss = 0.00759943
# Iteration 4, loss = 0.00714542
# Iteration 5, loss = 0.00667810
# Iteration 6, loss = 0.00660720
# Iteration 7, loss = 0.00657542
# Iteration 8, loss = 0.00655219
# Iteration 9, loss = 0.00653223
# Iteration 10, loss = 0.00651252
# Iteration 11, loss = 0.00649771
# Iteration 12, loss = 0.00648433
# Iteration 13, loss = 0.00647197
# Iteration 14, loss = 0.00646209
# Iteration 15, loss = 0.00645302
# Iteration 16, loss = 0.00644390
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# First round:
# [[0.1        0.50505051]
#  [0.3        0.46464646]
#  [0.5        0.43434343]
#  [0.7        0.41414141]
#  [0.9        0.39393939]]
# Second round:
# [[0.1        0.51515152]
#  [0.3        0.63636364]
#  [0.5        0.04040404]
#  [0.7        0.75757576]
#  [0.9        1.        ]]
# Repeating iteration. Extreme values in 2nd round
# ########## Iteration:  11
#
# # Determined opt bids R1
# # End of R1
# # Determined opt bids R2
# Iteration 1, loss = 0.01089231
# Iteration 2, loss = 0.00763395
# Iteration 3, loss = 0.00741850
# Iteration 4, loss = 0.00679912
# Iteration 5, loss = 0.00661117
# Iteration 6, loss = 0.00655711
# Iteration 7, loss = 0.00651952
# Iteration 8, loss = 0.00649191
# Iteration 9, loss = 0.00646847
# Iteration 10, loss = 0.00644877
# Iteration 11, loss = 0.00643323
# Iteration 12, loss = 0.00641737
# Iteration 13, loss = 0.00640837
# Iteration 14, loss = 0.00639892
# Iteration 15, loss = 0.00639194
# Iteration 16, loss = 0.00638603
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# First round:
# [[0.1        0.53535354]
#  [0.3        0.48484848]
#  [0.5        0.43434343]
#  [0.7        0.4040404 ]
#  [0.9        0.38383838]]
# Second round:
# [[0.1        0.55555556]
#  [0.3        0.90909091]
#  [0.5        0.07070707]
#  [0.7        0.75757576]
#  [0.9        0.98989899]]
# ########## Iteration:  12
#
# # Determined opt bids R1
# # End of R1
# # Determined opt bids R2
# Iteration 1, loss = 0.02892353
# Iteration 2, loss = 0.00772689
# Iteration 3, loss = 0.00754698
# Iteration 4, loss = 0.00687230
# Iteration 5, loss = 0.00667412
# Iteration 6, loss = 0.00662942
# Iteration 7, loss = 0.00660425
# Iteration 8, loss = 0.00658229
# Iteration 9, loss = 0.00656265
# Iteration 10, loss = 0.00654623
# Iteration 11, loss = 0.00653121
# Iteration 12, loss = 0.00651638
# Iteration 13, loss = 0.00650230
# Iteration 14, loss = 0.00649076
# Iteration 15, loss = 0.00647669
# Iteration 16, loss = 0.00646452
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# First round:
# [[0.1        0.53535354]
#  [0.3        0.46464646]
#  [0.5        0.42424242]
#  [0.7        0.4040404 ]
#  [0.9        0.4040404 ]]
# Second round:
# [[0.1        0.55555556]
#  [0.3        0.68686869]
#  [0.5        0.01010101]
#  [0.7        0.75757576]
#  [0.9        0.98989899]]
# ########## Iteration:  13
#
# # Determined opt bids R1
# # End of R1
# # Determined opt bids R2
# Iteration 1, loss = 0.01347937
# Iteration 2, loss = 0.00761682
# Iteration 3, loss = 0.00694760
# Iteration 4, loss = 0.00666955
# Iteration 5, loss = 0.00660765
# Iteration 6, loss = 0.00657447
# Iteration 7, loss = 0.00654607
# Iteration 8, loss = 0.00651968
# Iteration 9, loss = 0.00649802
# Iteration 10, loss = 0.00647962
# Iteration 11, loss = 0.00646442
# Iteration 12, loss = 0.00644942
# Iteration 13, loss = 0.00643733
# Iteration 14, loss = 0.00642585
# Iteration 15, loss = 0.00641839
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# First round:
# [[0.1        0.51515152]
#  [0.3        0.45454545]
#  [0.5        0.42424242]
#  [0.7        0.4040404 ]
#  [0.9        0.39393939]]
# Second round:
# [[0.1        0.53535354]
#  [0.3        0.66666667]
#  [0.5        0.03030303]
#  [0.7        0.24242424]
#  [0.9        0.33333333]]
# ########## Iteration:  14
#
# # Determined opt bids R1
# # End of R1
# # Determined opt bids R2
# Iteration 1, loss = 0.00818747
# Iteration 2, loss = 0.00762678
# Iteration 3, loss = 0.00700341
# Iteration 4, loss = 0.00658793
# Iteration 5, loss = 0.00653652
# Iteration 6, loss = 0.00651065
# Iteration 7, loss = 0.00649211
# Iteration 8, loss = 0.00647303
# Iteration 9, loss = 0.00645660
# Iteration 10, loss = 0.00643973
# Iteration 11, loss = 0.00642349
# Iteration 12, loss = 0.00640800
# Iteration 13, loss = 0.00639676
# Iteration 14, loss = 0.00638414
# Iteration 15, loss = 0.00637520
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# First round:
# [[0.1        0.51515152]
#  [0.3        0.46464646]
#  [0.5        0.43434343]
#  [0.7        0.41414141]
#  [0.9        0.39393939]]
# Second round:
# [[0.1        0.53535354]
#  [0.3        0.88888889]
#  [0.5        0.        ]
#  [0.7        0.75757576]
#  [0.9        1.        ]]
# Repeating iteration. Extreme values in 2nd round
# ########## Iteration:  15
#
# # Determined opt bids R1
# # End of R1
# # Determined opt bids R2
# Iteration 1, loss = 0.00960053
# Iteration 2, loss = 0.00775475
# Iteration 3, loss = 0.00764068
# Iteration 4, loss = 0.00697571
# Iteration 5, loss = 0.00665380
# Iteration 6, loss = 0.00660083
# Iteration 7, loss = 0.00657106
# Iteration 8, loss = 0.00654516
# Iteration 9, loss = 0.00652194
# Iteration 10, loss = 0.00650445
# Iteration 11, loss = 0.00648559
# Iteration 12, loss = 0.00647140
# Iteration 13, loss = 0.00645774
# Iteration 14, loss = 0.00644824
# Iteration 15, loss = 0.00643963
# Iteration 16, loss = 0.00642971
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# First round:
# [[0.1        0.54545455]
#  [0.3        0.46464646]
#  [0.5        0.42424242]
#  [0.7        0.4040404 ]
#  [0.9        0.39393939]]
# Second round:
# [[0.1        0.58585859]
#  [0.3        0.73737374]
#  [0.5        0.        ]
#  [0.7        0.        ]
#  [0.9        0.        ]]
# Repeating iteration. Extreme values in 2nd round
# ########## Iteration:  16
#
# # Determined opt bids R1
# # End of R1
# # Determined opt bids R2
# Iteration 1, loss = 0.00818481
# Iteration 2, loss = 0.00757186
# Iteration 3, loss = 0.00687998
# Iteration 4, loss = 0.00664796
# Iteration 5, loss = 0.00659683
# Iteration 6, loss = 0.00655047
# Iteration 7, loss = 0.00649869
# Iteration 8, loss = 0.00645893
# Iteration 9, loss = 0.00643091
# Iteration 10, loss = 0.00640753
# Iteration 11, loss = 0.00639033
# Iteration 12, loss = 0.00637757
# Iteration 13, loss = 0.00636931
# Iteration 14, loss = 0.00636209
# Iteration 15, loss = 0.00635721
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# First round:
# [[0.1        0.52525253]
#  [0.3        0.47474747]
#  [0.5        0.43434343]
#  [0.7        0.41414141]
#  [0.9        0.39393939]]
# Second round:
# [[0.1        0.56565657]
#  [0.3        0.6969697 ]
#  [0.5        0.09090909]
#  [0.7        0.25252525]
#  [0.9        0.35353535]]
# ########## Iteration:  17
# # Determined opt bids R1
# # End of R1
# # Determined opt bids R2
# Iteration 1, loss = 0.00954262
# Iteration 2, loss = 0.00741070
# Iteration 3, loss = 0.00678779
# Iteration 4, loss = 0.00668851
# Iteration 5, loss = 0.00665341
# Iteration 6, loss = 0.00662724
# Iteration 7, loss = 0.00660771
# Iteration 8, loss = 0.00658973
# Iteration 9, loss = 0.00657460
# Iteration 10, loss = 0.00656047
# Iteration 11, loss = 0.00654811
# Iteration 12, loss = 0.00653851
# Iteration 13, loss = 0.00652958
# Iteration 14, loss = 0.00652164
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# First round:
# [[0.1        0.51515152]
#  [0.3        0.45454545]
#  [0.5        0.42424242]
#  [0.7        0.4040404 ]
#  [0.9        0.39393939]]
# Second round:
# [[0.1        0.52525253]
#  [0.3        0.75757576]
#  [0.5        0.        ]
#  [0.7        0.75757576]
#  [0.9        1.        ]]
# Repeating iteration. Extreme values in 2nd round
# ########## Iteration:  18
#
# # Determined opt bids R1
# # End of R1
# # Determined opt bids R2
# Iteration 1, loss = 0.00817674
# Iteration 2, loss = 0.00770527
# Iteration 3, loss = 0.00765205
# Iteration 4, loss = 0.00717829
# Iteration 5, loss = 0.00671239
# Iteration 6, loss = 0.00663356
# Iteration 7, loss = 0.00660276
# Iteration 8, loss = 0.00657826
# Iteration 9, loss = 0.00655738
# Iteration 10, loss = 0.00653885
# Iteration 11, loss = 0.00652240
# Iteration 12, loss = 0.00650557
# Iteration 13, loss = 0.00649400
# Iteration 14, loss = 0.00648057
# Iteration 15, loss = 0.00647275
# Iteration 16, loss = 0.00646088
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# First round:
# [[0.1        0.54545455]
#  [0.3        0.46464646]
#  [0.5        0.43434343]
#  [0.7        0.41414141]
#  [0.9        0.4040404 ]]
# Second round:
# [[0.1        0.55555556]
#  [0.3        0.6969697 ]
#  [0.5        0.        ]
#  [0.7        0.75757576]
#  [0.9        0.98989899]]
# Repeating iteration. Extreme values in 2nd round
# ########## Iteration:  19
#
# # Determined opt bids R1
# # End of R1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-205-a661bd13861f> in <module>()
#      15         inputs = prepare_data(n, model=None, start=True)
#      16     else:
# ---> 17         inputs = prepare_data(n, model=mlp, start=False)
#      18         # save this model
#      19         mlp_prev = mlp
#
# <ipython-input-204-762c7ed8451f> in prepare_data(n, model, start, n_bids)
#      69
#      70         # determine optimal bid
# ---> 71         X_r2_opponent = opt_bid(model, X_r2_opponent)
#      72         r2_remain_opponent = X_r2_opponent[:,0]
#      73         r2_act_lost_opponent = X_r2_opponent[:,1]
#
# <ipython-input-167-9739c2b48163> in opt_bid(model, X)
#      49
#      50     # keep only best bids
# ---> 51     unique_keys, indices = np.unique(cand_res[:,2], return_index=True)
#      52     cand_res = cand_res[indices,:]
#      53
#
# ~\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     231     ar = np.asanyarray(ar)
#     232     if axis is None:
# --> 233         ret = _unique1d(ar, return_index, return_inverse, return_counts)
#     234         return _unpack_tuple(ret)
#     235
#
# ~\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     277     if optional_indices:
#     278         perm = ar.argsort(kind='mergesort' if return_index else 'quicksort')
# --> 279         aux = ar[perm]
#     280     else:
#     281         ar.sort()
#
# KeyboardInterrupt:

# %%
np.round(vector_opt_bids_r1,3)
# Out:
# array([[0.1  , 0.455, 0.495, 0.606, 0.545, 0.556, 0.485, 0.556, 0.475,
#         0.515, 0.556, 0.505, 0.535, 0.535, 0.515, 0.515, 0.545, 0.525,
#         0.515, 0.545],
#        [0.3  , 0.404, 0.434, 0.455, 0.434, 0.444, 0.444, 0.475, 0.404,
#         0.465, 0.485, 0.465, 0.485, 0.465, 0.455, 0.465, 0.465, 0.475,
#         0.455, 0.465],
#        [0.5  , 0.374, 0.404, 0.404, 0.414, 0.414, 0.414, 0.424, 0.364,
#         0.424, 0.434, 0.434, 0.434, 0.424, 0.424, 0.434, 0.424, 0.434,
#         0.424, 0.434],
#        [0.7  , 0.343, 0.394, 0.384, 0.394, 0.394, 0.404, 0.404, 0.364,
#         0.404, 0.414, 0.414, 0.404, 0.404, 0.404, 0.414, 0.404, 0.414,
#         0.404, 0.414],
#        [0.9  , 0.323, 0.384, 0.374, 0.384, 0.384, 0.394, 0.394, 0.384,
#         0.394, 0.394, 0.394, 0.384, 0.404, 0.394, 0.394, 0.394, 0.394,
#         0.394, 0.404]])

# %%
np.savetxt("vector_opt_bids_r1.csv", vector_opt_bids_r1, delimiter=",")

# %%
np.savetxt("vector_opt_bids_r2.csv", vector_opt_bids_r2, delimiter=",")
