# %%
import numpy as np
from scipy import stats

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import classification_report, confusion_matrix

# %%
def calculate_result(val_player, val_opponent, action_player, action_opponent):
    '''Function that calsulates auction result'''
    
    bid_player   = val_player*action_player
    bid_opponent = val_opponent*action_opponent
    
    win_player = (bid_player>bid_opponent)*(val_player-bid_player)
    
    return win_player

def prepare_data(n, model=None, start=False, n_bids=100):
    '''Prepare X and y for the neural network'''
    
    # valuations and actions of the player
    val_player   = np.random.beta(1,1,n)
    action_player  = np.random.beta(1,1,n)
    val_opponent = np.random.beta(1,1,n)
    
    # if first iteration - opponent plays randomly
    if start==True:
        action_opponent = np.random.beta(1,1,n)
        opponent = np.concatenate((val_opponent.reshape(n,1), action_opponent.reshape(n,1)), axis=1)
    else:
        # opponent chooses optimal bid given his valuation
        val_opponent = np.repeat(val_opponent, n_bids)
        action_opponent = np.tile(np.linspace(start=0, stop=1, num=n_bids), n)
        
        # gather private values and bids together
        opponent = np.concatenate((val_opponent.reshape(n*n_bids,1), action_opponent.reshape(n*n_bids,1)), axis=1)
        
        # determine optimal bid
        opponent = opt_bid(model, opponent)
    
    # outcome of the auction
    y = calculate_result(val_player, opponent[:,0], action_player, opponent[:,1])
    
    X = np.concatenate((val_player.reshape(n,1), action_player.reshape(n,1)), axis=1)
    y = np.reshape(y ,[n,]) 
    
    return X, y

def fit_model(X, y):
    
    # create a neural network
    mlp = MLPRegressor(alpha=0.001, hidden_layer_sizes = (10,5,3), max_iter = 1000, 
                   activation = 'logistic', verbose = True, learning_rate = 'adaptive')
    # fit model
    mlp.fit(X, y)
    
    return mlp

def opt_bid(model, X):
    '''Find bid with the highest expected profit'''
    
    # predict expected profit for each pair
    cand_predict = model.predict(X)
    cand_predict[cand_predict <= 0] = 0
    cand_predict[cand_predict >= 1] = 1

    # add expected profit to cand
    cand_res = np.concatenate((X, cand_predict.reshape(X.shape[0],1)), axis=1)

    # sort cand_res in descending order by the expected profit
    cand_res = cand_res[cand_res[:,2].argsort()[::-1],:]

    # keep only best bids
    unique_keys, indices = np.unique(cand_res[:,0], return_index=True)
    cand_res = cand_res[indices,:]
    
    
    return cand_res

def track_progress(model):
    n_val = 5
    n_bids = 100
    n_total = n_val*n_bids

    # create private values and bids
    val_player = np.repeat([0.1, 0.3, 0.5, 0.7, 0.9], n_bids)
    action_player = np.tile(np.linspace(start=0, stop=1, num=n_bids), n_val)

    # gather private values and bids together
    cand = np.concatenate((val_player.reshape(n_total,1), action_player.reshape(n_total,1)), axis=1)
    
    return opt_bid(model, cand)

# %% [markdown]
# ### 20 iterations - uniform distribution of bits

# %%
np.random.seed(4)

# number of observations in the dataset
n = 1000000

vector_opt_bids = np.array([0.1, 0.3, 0.5, 0.7, 0.9]).reshape(5,1)

for iter in range(20):
    
    print("Iteration #", iter, "\n")
    
    # prepare data
    if iter==0:
        X, y = prepare_data(n, start=True)
    else:
        X, y = prepare_data(n, model=mlp)
        # save this model
        mlp_prev = mlp
        
    # fit the model
    mlp = fit_model(X, y)
    
    # print optimal bids
    vector_opt_bids = np.concatenate((vector_opt_bids, track_progress(mlp)[:,1].reshape(5,1)), axis=1)
    print(vector_opt_bids[:,[0,-1]])
    
    # if there are extreme values in vector_opt_bids - repeat the iteration
    if (np.sum(vector_opt_bids[:,-1]==0) + np.sum(vector_opt_bids[:,-1]==1))!=0:
        print("Repeating iteration")
        mlp = mlp_prev

    del X,y
# Out:
# Iteration # 0
#
# Iteration 1, loss = 0.01691083
# Iteration 2, loss = 0.01237798
# Iteration 3, loss = 0.01155421
# Iteration 4, loss = 0.01105079
# Iteration 5, loss = 0.01100820
# Iteration 6, loss = 0.01098545
# Iteration 7, loss = 0.01097146
# Iteration 8, loss = 0.01095536
# Iteration 9, loss = 0.01094171
# Iteration 10, loss = 0.01092981
# Iteration 11, loss = 0.01091858
# Iteration 12, loss = 0.01090712
# Iteration 13, loss = 0.01089748
# Iteration 14, loss = 0.01088757
# Iteration 15, loss = 0.01087913
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.44444444]
#  [0.3        0.38383838]
#  [0.5        0.36363636]
#  [0.7        0.36363636]
#  [0.9        0.37373737]]
# Iteration # 1
#
# Iteration 1, loss = 0.01382360
# Iteration 2, loss = 0.00949384
# Iteration 3, loss = 0.00837712
# Iteration 4, loss = 0.00831913
# Iteration 5, loss = 0.00828788
# Iteration 6, loss = 0.00825983
# Iteration 7, loss = 0.00823914
# Iteration 8, loss = 0.00821786
# Iteration 9, loss = 0.00819873
# Iteration 10, loss = 0.00818165
# Iteration 11, loss = 0.00816523
# Iteration 12, loss = 0.00815307
# Iteration 13, loss = 0.00813807
# Iteration 14, loss = 0.00812699
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.53535354]
#  [0.3        0.47474747]
#  [0.5        0.43434343]
#  [0.7        0.42424242]
#  [0.9        0.41414141]]
# Iteration # 2
#
# Iteration 1, loss = 0.05607776
# Iteration 2, loss = 0.01292543
# Iteration 3, loss = 0.00964316
# Iteration 4, loss = 0.00838378
# Iteration 5, loss = 0.00826056
# Iteration 6, loss = 0.00820054
# Iteration 7, loss = 0.00815907
# Iteration 8, loss = 0.00812589
# Iteration 9, loss = 0.00809770
# Iteration 10, loss = 0.00807794
# Iteration 11, loss = 0.00805936
# Iteration 12, loss = 0.00804118
# Iteration 13, loss = 0.00802767
# Iteration 14, loss = 0.00801534
# Iteration 15, loss = 0.00800155
# Iteration 16, loss = 0.00799326
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.57575758]
#  [0.3        0.50505051]
#  [0.5        0.47474747]
#  [0.7        0.45454545]
#  [0.9        0.44444444]]
# Iteration # 3
#
# Iteration 1, loss = 0.01584957
# Iteration 2, loss = 0.01063334
# Iteration 3, loss = 0.01014514
# Iteration 4, loss = 0.00863638
# Iteration 5, loss = 0.00830672
# Iteration 6, loss = 0.00825941
# Iteration 7, loss = 0.00822690
# Iteration 8, loss = 0.00819630
# Iteration 9, loss = 0.00816893
# Iteration 10, loss = 0.00814223
# Iteration 11, loss = 0.00811644
# Iteration 12, loss = 0.00809498
# Iteration 13, loss = 0.00807427
# Iteration 14, loss = 0.00805784
# Iteration 15, loss = 0.00804397
# Iteration 16, loss = 0.00803116
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.76767677]
#  [0.3        0.55555556]
#  [0.5        0.49494949]
#  [0.7        0.47474747]
#  [0.9        0.45454545]]
# Iteration # 4
#
# Iteration 1, loss = 0.01112275
# Iteration 2, loss = 0.00986169
# Iteration 3, loss = 0.00863624
# Iteration 4, loss = 0.00843878
# Iteration 5, loss = 0.00838177
# Iteration 6, loss = 0.00834937
# Iteration 7, loss = 0.00832533
# Iteration 8, loss = 0.00829518
# Iteration 9, loss = 0.00826571
# Iteration 10, loss = 0.00823541
# Iteration 11, loss = 0.00820493
# Iteration 12, loss = 0.00817244
# Iteration 13, loss = 0.00814280
# Iteration 14, loss = 0.00811244
# Iteration 15, loss = 0.00808519
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.66666667]
#  [0.3        0.55555556]
#  [0.5        0.49494949]
#  [0.7        0.47474747]
#  [0.9        0.45454545]]
# Iteration # 5
#
# Iteration 1, loss = 0.01302636
# Iteration 2, loss = 0.01064525
# Iteration 3, loss = 0.00982313
# Iteration 4, loss = 0.00889647
# Iteration 5, loss = 0.00871963
# Iteration 6, loss = 0.00866628
# Iteration 7, loss = 0.00863301
# Iteration 8, loss = 0.00860469
# Iteration 9, loss = 0.00857798
# Iteration 10, loss = 0.00855448
# Iteration 11, loss = 0.00853160
# Iteration 12, loss = 0.00851189
# Iteration 13, loss = 0.00849526
# Iteration 14, loss = 0.00847628
# Iteration 15, loss = 0.00846069
# Iteration 16, loss = 0.00844711
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.64646465]
#  [0.3        0.54545455]
#  [0.5        0.50505051]
#  [0.7        0.47474747]
#  [0.9        0.46464646]]
# Iteration # 6
#
# Iteration 1, loss = 0.01096966
# Iteration 2, loss = 0.00988084
# Iteration 3, loss = 0.00855498
# Iteration 4, loss = 0.00824915
# Iteration 5, loss = 0.00819254
# Iteration 6, loss = 0.00816075
# Iteration 7, loss = 0.00813193
# Iteration 8, loss = 0.00810719
# Iteration 9, loss = 0.00808497
# Iteration 10, loss = 0.00806677
# Iteration 11, loss = 0.00804716
# Iteration 12, loss = 0.00803167
# Iteration 13, loss = 0.00801921
# Iteration 14, loss = 0.00800458
# Iteration 15, loss = 0.00799636
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.55555556]
#  [0.3        0.51515152]
#  [0.5        0.48484848]
#  [0.7        0.46464646]
#  [0.9        0.45454545]]
# Iteration # 7
#
# Iteration 1, loss = 0.01648481
# Iteration 2, loss = 0.01010996
# Iteration 3, loss = 0.00875764
# Iteration 4, loss = 0.00856103
# Iteration 5, loss = 0.00850664
# Iteration 6, loss = 0.00847029
# Iteration 7, loss = 0.00844435
# Iteration 8, loss = 0.00842395
# Iteration 9, loss = 0.00840471
# Iteration 10, loss = 0.00839073
# Iteration 11, loss = 0.00837582
# Iteration 12, loss = 0.00836537
# Iteration 13, loss = 0.00835500
# Iteration 14, loss = 0.00834656
# Iteration 15, loss = 0.00833943
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.54545455]
#  [0.3        0.50505051]
#  [0.5        0.48484848]
#  [0.7        0.47474747]
#  [0.9        0.46464646]]
# Iteration # 8
#
# Iteration 1, loss = 0.02044522
# Iteration 2, loss = 0.01064714
# Iteration 3, loss = 0.00969342
# Iteration 4, loss = 0.00874758
# Iteration 5, loss = 0.00861119
# Iteration 6, loss = 0.00855558
# Iteration 7, loss = 0.00851612
# Iteration 8, loss = 0.00848767
# Iteration 9, loss = 0.00846618
# Iteration 10, loss = 0.00844502
# Iteration 11, loss = 0.00842298
# Iteration 12, loss = 0.00840149
# Iteration 13, loss = 0.00837740
# Iteration 14, loss = 0.00835332
# Iteration 15, loss = 0.00832997
# Iteration 16, loss = 0.00830643
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.62626263]
#  [0.3        0.52525253]
#  [0.5        0.47474747]
#  [0.7        0.45454545]
#  [0.9        0.44444444]]
# Iteration # 9
#
# Iteration 1, loss = 0.02381268
# Iteration 2, loss = 0.01044482
# Iteration 3, loss = 0.00900962
# Iteration 4, loss = 0.00828927
# Iteration 5, loss = 0.00821150
# Iteration 6, loss = 0.00816931
# Iteration 7, loss = 0.00813349
# Iteration 8, loss = 0.00810046
# Iteration 9, loss = 0.00807056
# Iteration 10, loss = 0.00804149
# Iteration 11, loss = 0.00801212
# Iteration 12, loss = 0.00798697
# Iteration 13, loss = 0.00796606
# Iteration 14, loss = 0.00794458
# Iteration 15, loss = 0.00792641
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.63636364]
#  [0.3        0.54545455]
#  [0.5        0.48484848]
#  [0.7        0.45454545]
#  [0.9        0.44444444]]
# Iteration # 10
#
# Iteration 1, loss = 0.02508390
# Iteration 2, loss = 0.01047594
# Iteration 3, loss = 0.01044043
# Iteration 4, loss = 0.01042361
# Iteration 5, loss = 0.01017363
# Iteration 6, loss = 0.00865033
# Iteration 7, loss = 0.00830711
# Iteration 8, loss = 0.00824063
# Iteration 9, loss = 0.00819840
# Iteration 10, loss = 0.00816255
# Iteration 11, loss = 0.00813301
# Iteration 12, loss = 0.00810420
# Iteration 13, loss = 0.00807840
# Iteration 14, loss = 0.00805285
# Iteration 15, loss = 0.00802903
# Iteration 16, loss = 0.00800861
# Iteration 17, loss = 0.00798744
# Iteration 18, loss = 0.00796684
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.50505051]
#  [0.3        0.47474747]
#  [0.5        0.45454545]
#  [0.7        0.44444444]
#  [0.9        0.45454545]]
# Iteration # 11
#
# Iteration 1, loss = 0.01637573
# Iteration 2, loss = 0.01082580
# Iteration 3, loss = 0.00955150
# Iteration 4, loss = 0.00880641
# Iteration 5, loss = 0.00871308
# Iteration 6, loss = 0.00867270
# Iteration 7, loss = 0.00863569
# Iteration 8, loss = 0.00860313
# Iteration 9, loss = 0.00857038
# Iteration 10, loss = 0.00853953
# Iteration 11, loss = 0.00851251
# Iteration 12, loss = 0.00848978
# Iteration 13, loss = 0.00846744
# Iteration 14, loss = 0.00844768
# Iteration 15, loss = 0.00842958
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.57575758]
#  [0.3        0.51515152]
#  [0.5        0.47474747]
#  [0.7        0.44444444]
#  [0.9        0.43434343]]
# Iteration # 12
#
# Iteration 1, loss = 0.01148460
# Iteration 2, loss = 0.01038079
# Iteration 3, loss = 0.00880994
# Iteration 4, loss = 0.00824221
# Iteration 5, loss = 0.00818187
# Iteration 6, loss = 0.00814796
# Iteration 7, loss = 0.00812088
# Iteration 8, loss = 0.00809694
# Iteration 9, loss = 0.00807297
# Iteration 10, loss = 0.00805427
# Iteration 11, loss = 0.00803664
# Iteration 12, loss = 0.00801963
# Iteration 13, loss = 0.00800463
# Iteration 14, loss = 0.00798990
# Iteration 15, loss = 0.00797763
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.56565657]
#  [0.3        0.50505051]
#  [0.5        0.47474747]
#  [0.7        0.45454545]
#  [0.9        0.44444444]]
# Iteration # 13
#
# Iteration 1, loss = 0.01305280
# Iteration 2, loss = 0.01061081
# Iteration 3, loss = 0.00983200
# Iteration 4, loss = 0.00859518
# Iteration 5, loss = 0.00838830
# Iteration 6, loss = 0.00831405
# Iteration 7, loss = 0.00825677
# Iteration 8, loss = 0.00820899
# Iteration 9, loss = 0.00817108
# Iteration 10, loss = 0.00813984
# Iteration 11, loss = 0.00811705
# Iteration 12, loss = 0.00810248
# Iteration 13, loss = 0.00808807
# Iteration 14, loss = 0.00807623
# Iteration 15, loss = 0.00806657
# Iteration 16, loss = 0.00806079
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.        ]
#  [0.3        0.54545455]
#  [0.5        0.49494949]
#  [0.7        0.46464646]
#  [0.9        0.44444444]]
# Repeating iteration
# Iteration # 14
#
# Iteration 1, loss = 0.02068841
# Iteration 2, loss = 0.01034154
# Iteration 3, loss = 0.00866872
# Iteration 4, loss = 0.00836672
# Iteration 5, loss = 0.00831851
# Iteration 6, loss = 0.00828248
# Iteration 7, loss = 0.00825745
# Iteration 8, loss = 0.00823476
# Iteration 9, loss = 0.00821639
# Iteration 10, loss = 0.00819823
# Iteration 11, loss = 0.00818359
# Iteration 12, loss = 0.00817195
# Iteration 13, loss = 0.00816035
# Iteration 14, loss = 0.00815209
# Iteration 15, loss = 0.00814147
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.58585859]
#  [0.3        0.51515152]
#  [0.5        0.48484848]
#  [0.7        0.46464646]
#  [0.9        0.45454545]]
# Iteration # 15
#
# Iteration 1, loss = 0.01398420
# Iteration 2, loss = 0.00981429
# Iteration 3, loss = 0.00853672
# Iteration 4, loss = 0.00840482
# Iteration 5, loss = 0.00836596
# Iteration 6, loss = 0.00833752
# Iteration 7, loss = 0.00831070
# Iteration 8, loss = 0.00828782
# Iteration 9, loss = 0.00826676
# Iteration 10, loss = 0.00824382
# Iteration 11, loss = 0.00822581
# Iteration 12, loss = 0.00821034
# Iteration 13, loss = 0.00819320
# Iteration 14, loss = 0.00817636
# Iteration 15, loss = 0.00816365
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.54545455]
#  [0.3        0.49494949]
#  [0.5        0.46464646]
#  [0.7        0.45454545]
#  [0.9        0.44444444]]
# Iteration # 16
#
# Iteration 1, loss = 0.01730102
# Iteration 2, loss = 0.01079515
# Iteration 3, loss = 0.01066629
# Iteration 4, loss = 0.00965652
# Iteration 5, loss = 0.00858589
# Iteration 6, loss = 0.00839798
# Iteration 7, loss = 0.00831697
# Iteration 8, loss = 0.00826305
# Iteration 9, loss = 0.00822637
# Iteration 10, loss = 0.00819763
# Iteration 11, loss = 0.00817434
# Iteration 12, loss = 0.00815550
# Iteration 13, loss = 0.00814203
# Iteration 14, loss = 0.00813080
# Iteration 15, loss = 0.00812030
# Iteration 16, loss = 0.00811316
# Iteration 17, loss = 0.00810485
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.        ]
#  [0.3        0.55555556]
#  [0.5        0.49494949]
#  [0.7        0.46464646]
#  [0.9        0.44444444]]
# Repeating iteration
# Iteration # 17
#
# Iteration 1, loss = 0.04022462
# Iteration 2, loss = 0.01083793
# Iteration 3, loss = 0.01077556
# Iteration 4, loss = 0.01013445
# Iteration 5, loss = 0.00871784
# Iteration 6, loss = 0.00850069
# Iteration 7, loss = 0.00845316
# Iteration 8, loss = 0.00841955
# Iteration 9, loss = 0.00838856
# Iteration 10, loss = 0.00836320
# Iteration 11, loss = 0.00833891
# Iteration 12, loss = 0.00831733
# Iteration 13, loss = 0.00829893
# Iteration 14, loss = 0.00828078
# Iteration 15, loss = 0.00826226
# Iteration 16, loss = 0.00824603
# Iteration 17, loss = 0.00823358
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.55555556]
#  [0.3        0.51515152]
#  [0.5        0.48484848]
#  [0.7        0.46464646]
#  [0.9        0.44444444]]
# Iteration # 18
#
# Iteration 1, loss = 0.01382278
# Iteration 2, loss = 0.01066975
# Iteration 3, loss = 0.01065354
# Iteration 4, loss = 0.01063266
# Iteration 5, loss = 0.01037221
# Iteration 6, loss = 0.00908926
# Iteration 7, loss = 0.00840106
# Iteration 8, loss = 0.00833107
# Iteration 9, loss = 0.00829637
# Iteration 10, loss = 0.00826754
# Iteration 11, loss = 0.00824096
# Iteration 12, loss = 0.00821783
# Iteration 13, loss = 0.00819758
# Iteration 14, loss = 0.00817871
# Iteration 15, loss = 0.00816148
# Iteration 16, loss = 0.00814560
# Iteration 17, loss = 0.00813250
# Iteration 18, loss = 0.00811942
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.6969697 ]
#  [0.3        0.57575758]
#  [0.5        0.50505051]
#  [0.7        0.47474747]
#  [0.9        0.45454545]]
# Iteration # 19
#
# Iteration 1, loss = 0.01148273
# Iteration 2, loss = 0.01037253
# Iteration 3, loss = 0.01029020
# Iteration 4, loss = 0.00944915
# Iteration 5, loss = 0.00824357
# Iteration 6, loss = 0.00811335
# Iteration 7, loss = 0.00808325
# Iteration 8, loss = 0.00806074
# Iteration 9, loss = 0.00803817
# Iteration 10, loss = 0.00802284
# Iteration 11, loss = 0.00800543
# Iteration 12, loss = 0.00799148
# Iteration 13, loss = 0.00797821
# Iteration 14, loss = 0.00796777
# Iteration 15, loss = 0.00795666
# Iteration 16, loss = 0.00794787
# Iteration 17, loss = 0.00793797
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.5959596 ]
#  [0.3        0.55555556]
#  [0.5        0.52525253]
#  [0.7        0.49494949]
#  [0.9        0.46464646]]

# %%
np.round(vector_opt_bids,3)
# Out:
# array([[0.1  , 0.444, 0.535, 0.576, 0.768, 0.667, 0.646, 0.556, 0.545,
#         0.626, 0.636, 0.505, 0.576, 0.566, 0.   , 0.586, 0.545, 0.   ,
#         0.556, 0.697, 0.596],
#        [0.3  , 0.384, 0.475, 0.505, 0.556, 0.556, 0.545, 0.515, 0.505,
#         0.525, 0.545, 0.475, 0.515, 0.505, 0.545, 0.515, 0.495, 0.556,
#         0.515, 0.576, 0.556],
#        [0.5  , 0.364, 0.434, 0.475, 0.495, 0.495, 0.505, 0.485, 0.485,
#         0.475, 0.485, 0.455, 0.475, 0.475, 0.495, 0.485, 0.465, 0.495,
#         0.485, 0.505, 0.525],
#        [0.7  , 0.364, 0.424, 0.455, 0.475, 0.475, 0.475, 0.465, 0.475,
#         0.455, 0.455, 0.444, 0.444, 0.455, 0.465, 0.465, 0.455, 0.465,
#         0.465, 0.475, 0.495],
#        [0.9  , 0.374, 0.414, 0.444, 0.455, 0.455, 0.465, 0.455, 0.465,
#         0.444, 0.444, 0.455, 0.434, 0.444, 0.444, 0.455, 0.444, 0.444,
#         0.444, 0.455, 0.465]])

# %%
np.savetxt("sealed_bid.csv", vector_opt_bids, delimiter=",")

# %% [markdown]
# ### Exponential distribution

# %%
def prepare_data(n, model=None, start=False, n_bids=100):
    '''Prepare X and y for the neural network'''
    
    # valuations and actions of the player
    val_player   = np.random.exponential(0.5,n)
    action_player  = np.random.exponential(0.5,n)
    val_opponent = np.random.exponential(0.5,n)
    
    # if first iteration - opponent plays randomly
    if start==True:
        action_opponent = np.random.exponential(0.5,n)
        opponent = np.concatenate((val_opponent.reshape(n,1), action_opponent.reshape(n,1)), axis=1)
    else:
        # opponent chooses optimal bid given his valuation
        val_opponent = np.repeat(val_opponent, n_bids)
        action_opponent = np.tile(np.linspace(start=0, stop=1, num=n_bids), n)
        
        # gather private values and bids together
        opponent = np.concatenate((val_opponent.reshape(n*n_bids,1), action_opponent.reshape(n*n_bids,1)), axis=1)
        
        # determine optimal bid
        opponent = opt_bid(model, opponent)
    
    # outcome of the auction
    y = calculate_result(val_player, opponent[:,0], action_player, opponent[:,1])
    
    X = np.concatenate((val_player.reshape(n,1), action_player.reshape(n,1)), axis=1)
    y = np.reshape(y ,[n,]) 
    
    return X, y


def opt_bid(model, X):
    '''Find bid with the highest expected profit'''
    
    # predict expected profit for each pair
    cand_predict = model.predict(X)
    cand_predict[cand_predict <= 0] = 0

    # add expected profit to cand
    cand_res = np.concatenate((X, cand_predict.reshape(X.shape[0],1)), axis=1)

    # sort cand_res in descending order by the expected profit
    cand_res = cand_res[cand_res[:,2].argsort()[::-1],:]

    # keep only best bids
    unique_keys, indices = np.unique(cand_res[:,0], return_index=True)
    cand_res = cand_res[indices,:]
    
    
    return cand_res

# %%
np.random.seed(4)

# number of observations in the dataset
n = 1000000

vector_opt_bids = np.array([0.1, 0.3, 0.5, 0.7, 0.9]).reshape(5,1)

for iter in range(20):
    
    print("Iteration #", iter, "\n")
    
    # prepare data
    if iter==0:
        X, y = prepare_data(n, start=True)
    else:
        X, y = prepare_data(n, model=mlp)
        # save this model
        mlp_prev = mlp
        
    # fit the model
    mlp = fit_model(X, y)
    
    # print optimal bids
    vector_opt_bids = np.concatenate((vector_opt_bids, track_progress(mlp)[:,1].reshape(5,1)), axis=1)
    print(vector_opt_bids[:,[0,-1]])
    
    # if there are extreme values in vector_opt_bids - repeat the iteration
    if (np.sum(vector_opt_bids[:,-1]==0) + np.sum(vector_opt_bids[:,-1]==1))!=0:
        print("Repeating iteration")
        mlp = mlp_prev

    del X,y
# Out:
# Iteration # 0
#
# Iteration 1, loss = 0.05054755
# Iteration 2, loss = 0.03422318
# Iteration 3, loss = 0.02852051
# Iteration 4, loss = 0.02612119
# Iteration 5, loss = 0.02491992
# Iteration 6, loss = 0.02426299
# Iteration 7, loss = 0.02381059
# Iteration 8, loss = 0.02336901
# Iteration 9, loss = 0.02289992
# Iteration 10, loss = 0.02249168
# Iteration 11, loss = 0.02215323
# Iteration 12, loss = 0.02189557
# Iteration 13, loss = 0.02173462
# Iteration 14, loss = 0.02161906
# Iteration 15, loss = 0.02153530
# Iteration 16, loss = 0.02148089
# Iteration 17, loss = 0.02142071
# Iteration 18, loss = 0.02138722
# Iteration 19, loss = 0.02134820
# Iteration 20, loss = 0.02131278
# Iteration 21, loss = 0.02128682
# Iteration 22, loss = 0.02126383
# Iteration 23, loss = 0.02123456
# Iteration 24, loss = 0.02121000
# Iteration 25, loss = 0.02119050
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.61616162]
#  [0.3        0.26262626]
#  [0.5        0.26262626]
#  [0.7        0.26262626]
#  [0.9        0.26262626]]
# Iteration # 1
#
# Iteration 1, loss = 0.05104973
# Iteration 2, loss = 0.03889641
# Iteration 3, loss = 0.02606774
# Iteration 4, loss = 0.01921189
# Iteration 5, loss = 0.01704313
# Iteration 6, loss = 0.01614372
# Iteration 7, loss = 0.01562166
# Iteration 8, loss = 0.01532070
# Iteration 9, loss = 0.01510654
# Iteration 10, loss = 0.01494266
# Iteration 11, loss = 0.01482134
# Iteration 12, loss = 0.01470484
# Iteration 13, loss = 0.01461631
# Iteration 14, loss = 0.01453733
# Iteration 15, loss = 0.01446301
# Iteration 16, loss = 0.01439041
# Iteration 17, loss = 0.01430545
# Iteration 18, loss = 0.01419717
# Iteration 19, loss = 0.01410038
# Iteration 20, loss = 0.01403255
# Iteration 21, loss = 0.01398747
# Iteration 22, loss = 0.01395283
# Iteration 23, loss = 0.01393067
# Iteration 24, loss = 0.01389100
# Iteration 25, loss = 0.01386923
# Iteration 26, loss = 0.01384825
# Iteration 27, loss = 0.01383501
# Iteration 28, loss = 0.01382150
# Iteration 29, loss = 0.01380048
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.57575758]
#  [0.3        0.47474747]
#  [0.5        0.37373737]
#  [0.7        0.3030303 ]
#  [0.9        0.26262626]]
# Iteration # 2
#
# Iteration 1, loss = 0.04644504
# Iteration 2, loss = 0.04166259
# Iteration 3, loss = 0.03974377
# Iteration 4, loss = 0.02648955
# Iteration 5, loss = 0.01858459
# Iteration 6, loss = 0.01658494
# Iteration 7, loss = 0.01554917
# Iteration 8, loss = 0.01494522
# Iteration 9, loss = 0.01461562
# Iteration 10, loss = 0.01441786
# Iteration 11, loss = 0.01427712
# Iteration 12, loss = 0.01417409
# Iteration 13, loss = 0.01408151
# Iteration 14, loss = 0.01397379
# Iteration 15, loss = 0.01388221
# Iteration 16, loss = 0.01381705
# Iteration 17, loss = 0.01375828
# Iteration 18, loss = 0.01371457
# Iteration 19, loss = 0.01367195
# Iteration 20, loss = 0.01363025
# Iteration 21, loss = 0.01359634
# Iteration 22, loss = 0.01356233
# Iteration 23, loss = 0.01353279
# Iteration 24, loss = 0.01350502
# Iteration 25, loss = 0.01347484
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.        ]
#  [0.3        0.41414141]
#  [0.5        0.36363636]
#  [0.7        0.32323232]
#  [0.9        0.3030303 ]]
# Repeating iteration
# Iteration # 3
#
# Iteration 1, loss = 0.06605667
# Iteration 2, loss = 0.04295197
# Iteration 3, loss = 0.04122252
# Iteration 4, loss = 0.03791114
# Iteration 5, loss = 0.02651099
# Iteration 6, loss = 0.02204486
# Iteration 7, loss = 0.01890374
# Iteration 8, loss = 0.01675195
# Iteration 9, loss = 0.01572830
# Iteration 10, loss = 0.01520866
# Iteration 11, loss = 0.01483233
# Iteration 12, loss = 0.01450487
# Iteration 13, loss = 0.01423977
# Iteration 14, loss = 0.01409648
# Iteration 15, loss = 0.01399815
# Iteration 16, loss = 0.01393610
# Iteration 17, loss = 0.01387260
# Iteration 18, loss = 0.01381740
# Iteration 19, loss = 0.01377024
# Iteration 20, loss = 0.01372230
# Iteration 21, loss = 0.01367951
# Iteration 22, loss = 0.01363553
# Iteration 23, loss = 0.01360612
# Iteration 24, loss = 0.01356461
# Iteration 25, loss = 0.01354884
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.        ]
#  [0.3        0.35353535]
#  [0.5        0.33333333]
#  [0.7        0.31313131]
#  [0.9        0.29292929]]
# Repeating iteration
# Iteration # 4
#
# Iteration 1, loss = 0.05913767
# Iteration 2, loss = 0.03655217
# Iteration 3, loss = 0.02324185
# Iteration 4, loss = 0.01781409
# Iteration 5, loss = 0.01584270
# Iteration 6, loss = 0.01511487
# Iteration 7, loss = 0.01462034
# Iteration 8, loss = 0.01430547
# Iteration 9, loss = 0.01411339
# Iteration 10, loss = 0.01397865
# Iteration 11, loss = 0.01389103
# Iteration 12, loss = 0.01382063
# Iteration 13, loss = 0.01376830
# Iteration 14, loss = 0.01372724
# Iteration 15, loss = 0.01368986
# Iteration 16, loss = 0.01366225
# Iteration 17, loss = 0.01362501
# Iteration 18, loss = 0.01359453
# Iteration 19, loss = 0.01355910
# Iteration 20, loss = 0.01354094
# Iteration 21, loss = 0.01351351
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.57575758]
#  [0.3        0.50505051]
#  [0.5        0.43434343]
#  [0.7        0.37373737]
#  [0.9        0.33333333]]
# Iteration # 5
#
# Iteration 1, loss = 0.04784431
# Iteration 2, loss = 0.03685176
# Iteration 3, loss = 0.02200430
# Iteration 4, loss = 0.01869382
# Iteration 5, loss = 0.01749773
# Iteration 6, loss = 0.01706592
# Iteration 7, loss = 0.01684628
# Iteration 8, loss = 0.01669510
# Iteration 9, loss = 0.01660086
# Iteration 10, loss = 0.01652180
# Iteration 11, loss = 0.01645465
# Iteration 12, loss = 0.01640499
# Iteration 13, loss = 0.01636361
# Iteration 14, loss = 0.01632732
# Iteration 15, loss = 0.01629584
# Iteration 16, loss = 0.01624983
# Iteration 17, loss = 0.01622698
# Iteration 18, loss = 0.01620789
# Iteration 19, loss = 0.01618702
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.39393939]
#  [0.3        0.39393939]
#  [0.5        0.37373737]
#  [0.7        0.35353535]
#  [0.9        0.33333333]]
# Iteration # 6
#
# Iteration 1, loss = 0.04685286
# Iteration 2, loss = 0.04098683
# Iteration 3, loss = 0.02846118
# Iteration 4, loss = 0.02071190
# Iteration 5, loss = 0.01876239
# Iteration 6, loss = 0.01780194
# Iteration 7, loss = 0.01733608
# Iteration 8, loss = 0.01708351
# Iteration 9, loss = 0.01692382
# Iteration 10, loss = 0.01681304
# Iteration 11, loss = 0.01673116
# Iteration 12, loss = 0.01664918
# Iteration 13, loss = 0.01658132
# Iteration 14, loss = 0.01652431
# Iteration 15, loss = 0.01646739
# Iteration 16, loss = 0.01642499
# Iteration 17, loss = 0.01638803
# Iteration 18, loss = 0.01634921
# Iteration 19, loss = 0.01630912
# Iteration 20, loss = 0.01628278
# Iteration 21, loss = 0.01624982
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.        ]
#  [0.3        0.34343434]
#  [0.5        0.33333333]
#  [0.7        0.31313131]
#  [0.9        0.29292929]]
# Repeating iteration
# Iteration # 7
#
# Iteration 1, loss = 0.05140531
# Iteration 2, loss = 0.04106405
# Iteration 3, loss = 0.02771255
# Iteration 4, loss = 0.02060697
# Iteration 5, loss = 0.01879672
# Iteration 6, loss = 0.01789295
# Iteration 7, loss = 0.01746000
# Iteration 8, loss = 0.01723803
# Iteration 9, loss = 0.01709656
# Iteration 10, loss = 0.01698701
# Iteration 11, loss = 0.01689609
# Iteration 12, loss = 0.01679901
# Iteration 13, loss = 0.01672830
# Iteration 14, loss = 0.01666180
# Iteration 15, loss = 0.01659798
# Iteration 16, loss = 0.01655768
# Iteration 17, loss = 0.01651982
# Iteration 18, loss = 0.01649390
# Iteration 19, loss = 0.01646667
# Iteration 20, loss = 0.01644560
# Iteration 21, loss = 0.01642922
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.34343434]
#  [0.3        0.33333333]
#  [0.5        0.33333333]
#  [0.7        0.31313131]
#  [0.9        0.29292929]]
# Iteration # 8
#
# Iteration 1, loss = 0.04623352
# Iteration 2, loss = 0.03968309
# Iteration 3, loss = 0.02491396
# Iteration 4, loss = 0.01987100
# Iteration 5, loss = 0.01801916
# Iteration 6, loss = 0.01713398
# Iteration 7, loss = 0.01677726
# Iteration 8, loss = 0.01659845
# Iteration 9, loss = 0.01649010
# Iteration 10, loss = 0.01639387
# Iteration 11, loss = 0.01631624
# Iteration 12, loss = 0.01625453
# Iteration 13, loss = 0.01618999
# Iteration 14, loss = 0.01612917
# Iteration 15, loss = 0.01607698
# Iteration 16, loss = 0.01603161
# Iteration 17, loss = 0.01597514
# Iteration 18, loss = 0.01593324
# Iteration 19, loss = 0.01588522
# Iteration 20, loss = 0.01586642
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.31313131]
#  [0.3        0.31313131]
#  [0.5        0.3030303 ]
#  [0.7        0.29292929]
#  [0.9        0.28282828]]
# Iteration # 9
#
# Iteration 1, loss = 0.05088905
# Iteration 2, loss = 0.04124747
# Iteration 3, loss = 0.03054841
# Iteration 4, loss = 0.02003253
# Iteration 5, loss = 0.01815154
# Iteration 6, loss = 0.01710834
# Iteration 7, loss = 0.01657499
# Iteration 8, loss = 0.01631714
# Iteration 9, loss = 0.01618273
# Iteration 10, loss = 0.01608558
# Iteration 11, loss = 0.01602627
# Iteration 12, loss = 0.01596695
# Iteration 13, loss = 0.01592140
# Iteration 14, loss = 0.01587799
# Iteration 15, loss = 0.01583130
# Iteration 16, loss = 0.01578688
# Iteration 17, loss = 0.01574860
# Iteration 18, loss = 0.01570171
# Iteration 19, loss = 0.01566775
# Iteration 20, loss = 0.01562462
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.3030303 ]
#  [0.3        0.3030303 ]
#  [0.5        0.29292929]
#  [0.7        0.27272727]
#  [0.9        0.26262626]]
# Iteration # 10
#
# Iteration 1, loss = 0.05150503
# Iteration 2, loss = 0.02505817
# Iteration 3, loss = 0.01958572
# Iteration 4, loss = 0.01771728
# Iteration 5, loss = 0.01697178
# Iteration 6, loss = 0.01657819
# Iteration 7, loss = 0.01632630
# Iteration 8, loss = 0.01614904
# Iteration 9, loss = 0.01601472
# Iteration 10, loss = 0.01591171
# Iteration 11, loss = 0.01581568
# Iteration 12, loss = 0.01574847
# Iteration 13, loss = 0.01569488
# Iteration 14, loss = 0.01563943
# Iteration 15, loss = 0.01559550
# Iteration 16, loss = 0.01554536
# Iteration 17, loss = 0.01551195
# Iteration 18, loss = 0.01548274
# Iteration 19, loss = 0.01545620
# Iteration 20, loss = 0.01542533
# Iteration 21, loss = 0.01539660
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.88888889]
#  [0.3        0.27272727]
#  [0.5        0.32323232]
#  [0.7        0.31313131]
#  [0.9        0.29292929]]
# Iteration # 11
#
# Iteration 1, loss = 0.05386134
# Iteration 2, loss = 0.03143100
# Iteration 3, loss = 0.02031710
# Iteration 4, loss = 0.01730066
# Iteration 5, loss = 0.01614147
# Iteration 6, loss = 0.01560522
# Iteration 7, loss = 0.01534102
# Iteration 8, loss = 0.01517975
# Iteration 9, loss = 0.01506549
# Iteration 10, loss = 0.01497895
# Iteration 11, loss = 0.01489689
# Iteration 12, loss = 0.01482778
# Iteration 13, loss = 0.01476550
# Iteration 14, loss = 0.01471376
# Iteration 15, loss = 0.01466144
# Iteration 16, loss = 0.01461472
# Iteration 17, loss = 0.01456326
# Iteration 18, loss = 0.01449332
# Iteration 19, loss = 0.01441142
# Iteration 20, loss = 0.01435177
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.41414141]
#  [0.3        0.37373737]
#  [0.5        0.33333333]
#  [0.7        0.29292929]
#  [0.9        0.27272727]]
# Iteration # 12
#
# Iteration 1, loss = 0.05714519
# Iteration 2, loss = 0.02508870
# Iteration 3, loss = 0.01994884
# Iteration 4, loss = 0.01816575
# Iteration 5, loss = 0.01724415
# Iteration 6, loss = 0.01682156
# Iteration 7, loss = 0.01658097
# Iteration 8, loss = 0.01642355
# Iteration 9, loss = 0.01631566
# Iteration 10, loss = 0.01624267
# Iteration 11, loss = 0.01616722
# Iteration 12, loss = 0.01612190
# Iteration 13, loss = 0.01607870
# Iteration 14, loss = 0.01604803
# Iteration 15, loss = 0.01600549
# Iteration 16, loss = 0.01598287
# Iteration 17, loss = 0.01594717
# Iteration 18, loss = 0.01593228
# Iteration 19, loss = 0.01591316
# Iteration 20, loss = 0.01588777
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.53535354]
#  [0.3        0.45454545]
#  [0.5        0.38383838]
#  [0.7        0.33333333]
#  [0.9        0.3030303 ]]
# Iteration # 13
#
# Iteration 1, loss = 0.04709375
# Iteration 2, loss = 0.03366120
# Iteration 3, loss = 0.02247322
# Iteration 4, loss = 0.01836169
# Iteration 5, loss = 0.01704418
# Iteration 6, loss = 0.01642808
# Iteration 7, loss = 0.01608760
# Iteration 8, loss = 0.01587285
# Iteration 9, loss = 0.01572022
# Iteration 10, loss = 0.01560038
# Iteration 11, loss = 0.01550385
# Iteration 12, loss = 0.01542269
# Iteration 13, loss = 0.01535357
# Iteration 14, loss = 0.01529568
# Iteration 15, loss = 0.01524621
# Iteration 16, loss = 0.01520579
# Iteration 17, loss = 0.01516791
# Iteration 18, loss = 0.01513260
# Iteration 19, loss = 0.01509993
# Iteration 20, loss = 0.01507000
# Iteration 21, loss = 0.01504305
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.64646465]
#  [0.3        0.47474747]
#  [0.5        0.36363636]
#  [0.7        0.32323232]
#  [0.9        0.3030303 ]]
# Iteration # 14
#
# Iteration 1, loss = 0.05604612
# Iteration 2, loss = 0.04135887
# Iteration 3, loss = 0.02781361
# Iteration 4, loss = 0.01920761
# Iteration 5, loss = 0.01681713
# Iteration 6, loss = 0.01595945
# Iteration 7, loss = 0.01550368
# Iteration 8, loss = 0.01521026
# Iteration 9, loss = 0.01500391
# Iteration 10, loss = 0.01484353
# Iteration 11, loss = 0.01471674
# Iteration 12, loss = 0.01460317
# Iteration 13, loss = 0.01450695
# Iteration 14, loss = 0.01442960
# Iteration 15, loss = 0.01436958
# Iteration 16, loss = 0.01431544
# Iteration 17, loss = 0.01427977
# Iteration 18, loss = 0.01424205
# Iteration 19, loss = 0.01420736
# Iteration 20, loss = 0.01418433
# Iteration 21, loss = 0.01415797
# Iteration 22, loss = 0.01413687
# Iteration 23, loss = 0.01411232
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.88888889]
#  [0.3        0.52525253]
#  [0.5        0.44444444]
#  [0.7        0.38383838]
#  [0.9        0.33333333]]
# Iteration # 15
#
# Iteration 1, loss = 0.06685099
# Iteration 2, loss = 0.03440695
# Iteration 3, loss = 0.02707105
# Iteration 4, loss = 0.02181619
# Iteration 5, loss = 0.01827706
# Iteration 6, loss = 0.01650368
# Iteration 7, loss = 0.01554373
# Iteration 8, loss = 0.01497441
# Iteration 9, loss = 0.01460982
# Iteration 10, loss = 0.01438031
# Iteration 11, loss = 0.01420148
# Iteration 12, loss = 0.01409644
# Iteration 13, loss = 0.01400918
# Iteration 14, loss = 0.01393400
# Iteration 15, loss = 0.01386688
# Iteration 16, loss = 0.01383102
# Iteration 17, loss = 0.01379065
# Iteration 18, loss = 0.01376021
# Iteration 19, loss = 0.01372231
# Iteration 20, loss = 0.01369985
# Iteration 21, loss = 0.01367586
# Iteration 22, loss = 0.01366656
# Iteration 23, loss = 0.01363959
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.67676768]
#  [0.3        0.53535354]
#  [0.5        0.43434343]
#  [0.7        0.37373737]
#  [0.9        0.34343434]]
# Iteration # 16
#
# Iteration 1, loss = 0.04973371
# Iteration 2, loss = 0.03269945
# Iteration 3, loss = 0.02142640
# Iteration 4, loss = 0.01808394
# Iteration 5, loss = 0.01673130
# Iteration 6, loss = 0.01612869
# Iteration 7, loss = 0.01582861
# Iteration 8, loss = 0.01564372
# Iteration 9, loss = 0.01551949
# Iteration 10, loss = 0.01542411
# Iteration 11, loss = 0.01535102
# Iteration 12, loss = 0.01527793
# Iteration 13, loss = 0.01522155
# Iteration 14, loss = 0.01515259
# Iteration 15, loss = 0.01508637
# Iteration 16, loss = 0.01502080
# Iteration 17, loss = 0.01497445
# Iteration 18, loss = 0.01493989
# Iteration 19, loss = 0.01490047
# Iteration 20, loss = 0.01487198
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.67676768]
#  [0.3        0.52525253]
#  [0.5        0.43434343]
#  [0.7        0.37373737]
#  [0.9        0.33333333]]
# Iteration # 17
#
# Iteration 1, loss = 0.04803324
# Iteration 2, loss = 0.04198623
# Iteration 3, loss = 0.04117890
# Iteration 4, loss = 0.03216943
# Iteration 5, loss = 0.02059561
# Iteration 6, loss = 0.01799069
# Iteration 7, loss = 0.01674068
# Iteration 8, loss = 0.01609689
# Iteration 9, loss = 0.01571868
# Iteration 10, loss = 0.01546019
# Iteration 11, loss = 0.01526721
# Iteration 12, loss = 0.01511445
# Iteration 13, loss = 0.01501518
# Iteration 14, loss = 0.01495133
# Iteration 15, loss = 0.01490415
# Iteration 16, loss = 0.01486291
# Iteration 17, loss = 0.01482989
# Iteration 18, loss = 0.01479471
# Iteration 19, loss = 0.01477057
# Iteration 20, loss = 0.01474765
# Iteration 21, loss = 0.01472781
# Iteration 22, loss = 0.01471178
# Iteration 23, loss = 0.01469132
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.        ]
#  [0.3        0.45454545]
#  [0.5        0.39393939]
#  [0.7        0.35353535]
#  [0.9        0.33333333]]
# Repeating iteration
# Iteration # 18
#
# Iteration 1, loss = 0.04517453
# Iteration 2, loss = 0.04026778
# Iteration 3, loss = 0.02876071
# Iteration 4, loss = 0.02104291
# Iteration 5, loss = 0.01859585
# Iteration 6, loss = 0.01728312
# Iteration 7, loss = 0.01668143
# Iteration 8, loss = 0.01634799
# Iteration 9, loss = 0.01611809
# Iteration 10, loss = 0.01594593
# Iteration 11, loss = 0.01580088
# Iteration 12, loss = 0.01568105
# Iteration 13, loss = 0.01558583
# Iteration 14, loss = 0.01549966
# Iteration 15, loss = 0.01542036
# Iteration 16, loss = 0.01534277
# Iteration 17, loss = 0.01527785
# Iteration 18, loss = 0.01522776
# Iteration 19, loss = 0.01517564
# Iteration 20, loss = 0.01513382
# Iteration 21, loss = 0.01509346
# Iteration 22, loss = 0.01505867
# Iteration 23, loss = 0.01501946
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.42424242]
#  [0.3        0.45454545]
#  [0.5        0.4040404 ]
#  [0.7        0.36363636]
#  [0.9        0.33333333]]
# Iteration # 19
#
# Iteration 1, loss = 0.05321245
# Iteration 2, loss = 0.03160411
# Iteration 3, loss = 0.02086435
# Iteration 4, loss = 0.01879020
# Iteration 5, loss = 0.01785322
# Iteration 6, loss = 0.01739721
# Iteration 7, loss = 0.01710618
# Iteration 8, loss = 0.01693028
# Iteration 9, loss = 0.01680037
# Iteration 10, loss = 0.01671539
# Iteration 11, loss = 0.01664870
# Iteration 12, loss = 0.01660257
# Iteration 13, loss = 0.01656116
# Iteration 14, loss = 0.01652501
# Iteration 15, loss = 0.01649821
# Iteration 16, loss = 0.01647637
# Iteration 17, loss = 0.01645807
# Iteration 18, loss = 0.01643439
# Iteration 19, loss = 0.01640875
# Iteration 20, loss = 0.01641022
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0.1        0.47474747]
#  [0.3        0.45454545]
#  [0.5        0.41414141]
#  [0.7        0.37373737]
#  [0.9        0.34343434]]

# %%
vector_opt_bids
# Out:
# array([[0.1       , 0.61616162, 0.57575758, 0.        , 0.        ,
#         0.57575758, 0.39393939, 0.        , 0.34343434, 0.31313131,
#         0.3030303 , 0.88888889, 0.41414141, 0.53535354, 0.64646465,
#         0.88888889, 0.67676768, 0.67676768, 0.        , 0.42424242,
#         0.47474747],
#        [0.3       , 0.26262626, 0.47474747, 0.41414141, 0.35353535,
#         0.50505051, 0.39393939, 0.34343434, 0.33333333, 0.31313131,
#         0.3030303 , 0.27272727, 0.37373737, 0.45454545, 0.47474747,
#         0.52525253, 0.53535354, 0.52525253, 0.45454545, 0.45454545,
#         0.45454545],
#        [0.5       , 0.26262626, 0.37373737, 0.36363636, 0.33333333,
#         0.43434343, 0.37373737, 0.33333333, 0.33333333, 0.3030303 ,
#         0.29292929, 0.32323232, 0.33333333, 0.38383838, 0.36363636,
#         0.44444444, 0.43434343, 0.43434343, 0.39393939, 0.4040404 ,
#         0.41414141],
#        [0.7       , 0.26262626, 0.3030303 , 0.32323232, 0.31313131,
#         0.37373737, 0.35353535, 0.31313131, 0.31313131, 0.29292929,
#         0.27272727, 0.31313131, 0.29292929, 0.33333333, 0.32323232,
#         0.38383838, 0.37373737, 0.37373737, 0.35353535, 0.36363636,
#         0.37373737],
#        [0.9       , 0.26262626, 0.26262626, 0.3030303 , 0.29292929,
#         0.33333333, 0.33333333, 0.29292929, 0.29292929, 0.28282828,
#         0.26262626, 0.29292929, 0.27272727, 0.3030303 , 0.3030303 ,
#         0.33333333, 0.34343434, 0.33333333, 0.33333333, 0.33333333,
#         0.34343434]])

# %%
np.savetxt("sealed_bid_exp.csv", vector_opt_bids, delimiter=",")
